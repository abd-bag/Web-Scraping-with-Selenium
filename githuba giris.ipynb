# %%
from selenium import webdriver 
import time
import requests

activities=[]

browser=webdriver.Chrome(r"C:\Users\iince\DS Projects\chromedriver_win32/chromedriver.exe")

browser.get("https://github.com/login")
time.sleep(5)

user_name=browser.find_element_by_name('login').send_keys('iince98@gmail.com')
pass_enter=browser.find_element_by_name('password').send_keys('Urf3292871**')
browser.find_element_by_name('commit').click()
time.sleep(5)

aa=browser.find_elements_by_tag_name('a')
for ii in aa:
    bb=ii.get_attribute('href')
    activities.append(ii.tag_name+ '\n'+ ii.text)
    
browser.close()

# %%
activities
#for jj in range(0, len(activities)):
#    print(activities[jj])
# Out:
# ['a\nSkip to content',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\nPull requests',
#  'a\nIssues',
#  'a\nMarketplace',
#  'a\nExplore',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\nNew repository',
#  'a\niince98\n/\nleetcode',
#  'a\nabd-bag\n/\nAriscon_Duss_Trn_All',
#  'a\niince98\n/\nPrime-Number-Finder',
#  'a\nbabayigit2088\n/\nleetcode',
#  'a\naydinmyilmaz\n/\nWebScrapping_Project',
#  'a\nabd-bag\n/\nWebScrapping_Project',
#  'a\nzeynelkaraoglu1\n/\nAriscon_Duss_Trn_All',
#  'a\nDiscover repositories',
#  'a\n',
#  'a\nabd-bag',
#  'a\nabd-bag/Ariscon_Duss_Trn_All',
#  'a\nmaster',
#  'a\n',
#  'a\n085844b',
#  'a\n',
#  'a\nabd-bag',
#  'a\nabd-bag/predict-next-purchase',
#  'a\nFeaturetools/predict-next-purchase',
#  'a\nFeaturetools/predict-next-purchase',
#  'a\n191',
#  'a\n',
#  'a\nabd-bag',
#  'a\nabd-bag/DataCamp',
#  'a\nariscon/DataCamp',
#  'a\nariscon/DataCamp',
#  'a\n',
#  'a\nbabayigit2088',
#  'a\nbabayigit2088/collection',
#  'a\ntategallery/collection',
#  'a\ntategallery/collection',
#  'a\n385',
#  'a\n',
#  'a\nabd-bag',
#  'a\nabd-bag/WebScrapping_Project',
#  'a\nabd-bag/WebScrapping_Project',
#  'a\n1',
#  'a\n',
#  'a\nbabayigit2088',
#  'a\nbabayigit2088/DataCamp',
#  'a\nariscon/DataCamp',
#  'a\nariscon/DataCamp',
#  'a\n',
#  'a\nabd-bag',
#  'a\nabd-bag/WebScrapping_Project',
#  'a\naydinmyilmaz/WebScrapping_Project',
#  'a\naydinmyilmaz/WebScrapping_Project',
#  'a\n1',
#  'a\n',
#  'a\nariscon',
#  'a\nariscon/DataCamp',
#  'a\nwblakecannon/DataCamp',
#  'a\nwblakecannon/DataCamp',
#  'a\n181',
#  'a\n',
#  'a\nbabayigit2088',
#  'a\nbabayigit2088/LeetCode-1',
#  'a\nPratul1997/LeetCode',
#  'a\nPratul1997/LeetCode',
#  'a\n6',
#  'a\n',
#  'a\ntuvtran',
#  'a\nyeyintminthuhtut/Awesome-Red-Teaming',
#  'a\n1.3k',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\nabd-bag',
#  'a\naydinmyilmaz/WebScrapping_Project',
#  'a\naydinmyilmaz/WebScrapping_Project',
#  'a\n1',
#  'a\n',
#  'a\nabd-bag',
#  'a\nabd-bag/Ariscon_Duss_Trn_All',
#  'a\nmaster',
#  'a\n',
#  'a\n44f8f28',
#  'a\n',
#  'a\n8ff85ea',
#  'a\n7 more commits »',
#  'a\n',
#  'a\nariscon',
#  'a\nariscon/Amazon_by_Ariscon',
#  'a\nzeynelkaraoglu1/Amazon_by_Ariscon',
#  'a\nzeynelkaraoglu1/Amazon_by_Ariscon',
#  'a\n',
#  'a\nzeynelkaraoglu1',
#  'a\nzeynelkaraoglu1/Amazon_by_Ariscon',
#  'a\nzeynelkaraoglu1/Amazon_by_Ariscon',
#  'a\n',
#  'a\nabd-bag',
#  'a\nabd-bag/Ariscon_Duss_Trn_All',
#  'a\nmaster',
#  'a\n',
#  'a\n6d66c2c',
#  'a\n',
#  'a\n4510040',
#  'a\n7 more commits »',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\nbabayigit2088',
#  'a\nBrManga',
#  'a\n',
#  'a\nManga',
#  'a\nBrManga',
#  'a\n8 repositories',
#  'a\n3 followers',
#  'a\n',
#  'a\nBrManga',
#  'a\n',
#  'a\nManga',
#  'a\nBrManga',
#  'a\n8 repositories',
#  'a\n3 followers',
#  'a\n',
#  'a\nihbaydas',
#  'a\nhugobowne',
#  'a\n',
#  'a\nHugo Bowne-Anderson',
#  'a\nhugobowne',
#  'a\n34 repositories',
#  'a\n364 followers',
#  'a\n',
#  'a\naydinmyilmaz',
#  'a\nozgur-caglayan',
#  'a\n',
#  'a\nozgur-caglayan',
#  'a\n6 repositories',
#  'a\n2 followers',
#  'a\n',
#  'a\nihbaydas',
#  'a\nariscon',
#  'a\n',
#  'a\nAriscon',
#  'a\nariscon',
#  'a\n8 repositories',
#  'a\n12 followers',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\nariscon',
#  'a\nariscon/Data_Camp_Notes',
#  'a\nariscon/Data_Camp_Notes',
#  'a\n',
#  'a\nzeynelkaraoglu1',
#  'a\nzeynelkaraoglu1/Data_Camp',
#  'a\nzeynelkaraoglu1/Data_Camp',
#  'a\n',
#  'a\nzeynelkaraoglu1',
#  'a\nzeynelkaraoglu1/Capstone-Projets',
#  'a\nzeynelkaraoglu1/Capstone-Projets',
#  'a\n',
#  'a\nariscon',
#  'a\nariscon/Tutorials',
#  'a\nariscon/Tutorials',
#  'a\n',
#  'a\nzeynelkaraoglu1',
#  'a\nzeynelkaraoglu1/Coursera_Project',
#  'a\nzeynelkaraoglu1/Coursera_Project',
#  'a\n',
#  'a\nzeynelkaraoglu1',
#  'a\nzeynelkaraoglu1/The-fake-album-cover-game',
#  'a\nchandru11235/The-fake-album-cover-game',
#  'a\nchandru11235/The-fake-album-cover-game',
#  'a\n',
#  'a\njustmarkham',
#  'a\njustmarkham/pandas',
#  'a\npandas-dev/pandas',
#  'a\npandas-dev/pandas',
#  'a\n17.4k',
#  'a\n',
#  'a\nMustafaKadioglu',
#  'a\nMustafaKadioglu/autokeras',
#  'a\njhfjhfj1/autokeras',
#  'a\n3.9k',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\n',
#  'a\nariscon',
#  'a\nariscon/machine-learning-project-walkthrough',
#  'a\nzeynelkaraoglu1/machine-learning-project-walkthrough',
#  'a\nzeynelkaraoglu1/machine-learning-project-walkthrough',
#  'a\n',
#  'a\nzeynelkaraoglu1',
#  'a\nzeynelkaraoglu1/machine-learning-project-walkthrough',
#  'a\nbabayigit2088/machine-learning-project-walkthrough',
#  'a\nbabayigit2088/machine-learning-project-walkthrough',
#  'a\nfollow',
#  'a\nwatch',
#  'a\nSubscribe to your news feed',
#  'a\nTerms',
#  'a\nPrivacy',
#  'a\nSecurity',
#  'a\nStatus',
#  'a\nHelp',
#  'a\n',
#  'a\nContact GitHub',
#  'a\nPricing',
#  'a\nAPI',
#  'a\nTraining',
#  'a\nBlog',
#  'a\nAbout',
#  'a\n',
#  'a\n']
